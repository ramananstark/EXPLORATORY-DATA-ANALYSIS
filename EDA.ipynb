# %%
import pandas as pd
import numpy as np
import os

# %%
path="Sales_Data"
files=[file for file in os.listdir(path)]

all_data=pd.DataFrame()
for file in files:
    data = pd.read_csv("Sales_Data/"+file)
    all_data=pd.concat([all_data,data])

all_data.to_csv("all_data.csv",index=False)

# %%
path="C:\\Users\\raman\\OneDrive\\Desktop\\something\\all_data.csv"
all_data=pd.read_csv(path)
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
all_data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
all_data = all_data.dropna()
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
#all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])
#print(all_data['Order Date'].dtype)
all_data=all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data['Quantity Ordered']=pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each']=pd.to_numeric(all_data['Price Each'])
all_data['Order Date']=pd.to_datetime(all_data['Order Date'])
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_11748\1650224686.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Order Date'].str[0:2]
# C:\Users\raman\AppData\Local\Temp\ipykernel_11748\1650224686.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Month'].astype('int32')
# C:\Users\raman\AppData\Local\Temp\ipykernel_11748\1650224686.py:3: SettingWithCopyWarning:
# ...

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data
all_data['City']= all_data['Purchase Address'].apply(lambda x: x.split(',')[1])
all_data
all_data['state']=all_data['Purchase Address'].apply(lambda x: x.split(',')[2].split(' ')[1])
all_data['City']=all_data['City'] + "-" + all_data['state']
all_data=all_data.drop(columns='state')
all_data['Hour']=all_data['Order Date'].dt.hour
all_data['Minute']=all_data['Order Date'].dt.minute
all_data
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_11748\985435242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
# C:\Users\raman\AppData\Local\Temp\ipykernel_11748\985435242.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['City']= all_data['Purchase Address'].apply(lambda x: x.split(',')[1])
# C:\Users\raman\AppData\Local\Temp\ipykernel_11748\985435242.py:5: SettingWithCopyWarning:
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
#  7   Sales             185950 non-null  float64
#  8   City              185950 non-null  object
#  9   Hour              185950 non-null  int64
#  10  Minute            185950 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(3), object(4)
# memory usage: 16.3+ MB

# %%
Month_Sales = all_data.groupby('Month').sum()
Month_Sales
# Out:
#        Quantity Ordered  Price Each       Sales    Hour  Minute
# Month
# 1                 10903  1811768.38  1822256.73  139485  282440
# 2                 13449  2188884.72  2202022.42  172669  354885
# 3                 17005  2791207.83  2807100.38  218969  447559
# 4                 20558  3367671.02  3390670.24  262259  544186
# 5                 18667  3135125.13  3152606.75  238780  487899
# 6                 15253  2562025.61  2577802.26  195528  402436
# 7                 16072  2632539.56  2647775.76  206169  417349
# 8                 13448  2230345.42  2244467.88  172289  353857
# 9                 13109  2084992.09  2097560.13  168513  341698
# 10                22703  3715554.83  3736726.88  290650  598437
# 11                19798  3180600.68  3199603.20  254865  518231
# 12                28114  4588415.41  4613443.34  359978  733082

# %%
import matplotlib.pyplot as plt
months = range(1,13)
plt.bar(months,Month_Sales['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD')
plt.xlabel('MOnth')
plt.title("Sales by Month")
plt.show()

# %%
City_Sales=all_data.groupby('City').sum().reset_index()
City_Sales
# Out:
#                 City  Quantity Ordered  Price Each   Month       Sales  \
# 0         Atlanta-GA             16602  2779908.20  104794  2795498.58
# 1          Austin-TX             11153  1809873.61   69829  1819581.75
# 2          Boston-MA             22528  3637409.77  141112  3661642.01
# 3          Dallas-TX             16730  2752627.82  104620  2767975.40
# 4     Los Angeles-CA             33289  5421435.23  208325  5452570.80
# 5   New York City-NY             27932  4635370.83  175741  4664317.43
# 6        Portland-ME              2750   447189.25   17144   449758.27
# 7        Portland-OR             11303  1860558.22   70621  1870732.34
# 8   San Francisco-CA             50239  8211461.74  315520  8262203.91
# 9         Seattle-WA             16553  2733296.01  104941  2747755.48
#
#      Hour   Minute
# 0  214264   442932
# 1  141946   289060
# 2  288225   590442
# 3  214390   435155
# 4  427444   866638
# 5  357696   733598
# 6   35211    72856
# 7  144421   295533
# ...

# %%
city=City_Sales['City']
sales=City_Sales['Sales']
#plt.figure(figsize=(12,4))
plt.bar(city,sales)
plt.xticks(city,rotation='vertical')
plt.xlabel('cities')
plt.ylabel('sales')
plt.title("sales by cities")
plt.show()

# %%
Hour_Sales=all_data.groupby('Hour').sum().reset_index()
Count = all_data.groupby('Hour').count()
x=Hour_Sales['Hour']
y=Count['Quantity Ordered']
plt.xticks(x)
plt.xlabel("time")
plt.ylabel("sales")
plt.plot(x,y)
plt.grid()
plt.title("Hour_Sales")
plt.show()

# %%
df=all_data[all_data['Order ID'].duplicated(keep=False)]
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 18       176574                Google Phone                 1      600.00
# 19       176574        USB-C Charging Cable                 1       11.95
# 30       176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186792   259303       AA Batteries (4-pack)                 1        3.84
# 186803   259314            Wired Headphones                 1       11.99
# 186804   259314      AAA Batteries (4-pack)                 2        2.99
# 186841   259350                Google Phone                 1      600.00
# 186842   259350        USB-C Charging Cable                 1       11.95
#
#                 Order Date                       Purchase Address  Month  \
# ...

# %%
all_data.groupby('Purchase Address').sum().sort_values(by=['Sales'],ascending=False)
# Out:
#                                         Quantity Ordered  Price Each  Month  \
# Purchase Address
# 668 Park St, San Francisco, CA 94016                   4     2679.99      9
# 795 1st St, Atlanta, GA 30301                          3     4100.00     28
# 391 1st St, Seattle, WA 98101                          3     4100.00     21
# 10 1st St, San Francisco, CA 94016                     3     4000.00     15
# 731 11th St, New York City, NY 10001                   6     2219.88     30
# ...                                                  ...         ...    ...
# 873 Hill St, San Francisco, CA 94016                   1        2.99      5
# 533 Church St, Austin, TX 73301                        1        2.99     12
# 873 Forest St, Boston, MA 02215                        1        2.99     12
# 533 Adams St, San Francisco, CA 94016                  1        2.99      6
# 816 Cherry St, New York City, NY 10001                 1        2.99      3
#
# ...

# %%
all_data.groupby('Order ID').sum().sort_values(by='Sales',ascending=False)
# Out:
#           Quantity Ordered  Price Each  Month    Sales  Hour  Minute
# Order ID
# 181069                   3     2079.99      8  3779.99    42       2
# 243728                   2     3400.00     16  3400.00    24     114
# 202212                   2     3400.00     10  3400.00    26      38
# 181544                   2     1700.00      4  3400.00    12      48
# 200528                   2     1700.00      5  3400.00    13      40
# ...                    ...         ...    ...      ...   ...     ...
# 155328                   1        2.99      2     2.99     9      30
# 178594                   1        2.99      4     2.99    19       8
# 268771                   1        2.99     10     2.99     8      54
# 248516                   1        2.99      9     2.99    18      32
# 178557                   1        2.99      4     2.99    20      26
#
# [178437 rows x 6 columns]

# %%
all_data.describe()
# Out:
#        Quantity Ordered     Price Each          Month          Sales  \
# count     185950.000000  185950.000000  185950.000000  185950.000000
# mean           1.124383     184.399735       7.059140     185.490917
# std            0.442793     332.731330       3.502996     332.919771
# min            1.000000       2.990000       1.000000       2.990000
# 25%            1.000000      11.950000       4.000000      11.950000
# 50%            1.000000      14.950000       7.000000      14.950000
# 75%            1.000000     150.000000      10.000000     150.000000
# max            9.000000    1700.000000      12.000000    3400.000000
#
#                 Hour         Minute
# count  185950.000000  185950.000000
# mean       14.413305      29.481361
# std         5.423416      17.317573
# min         0.000000       0.000000
# 25%        11.000000      14.000000
# 50%        15.000000      29.000000
# 75%        19.000000      45.000000
# max        23.000000      59.000000

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
#  7   Sales             185950 non-null  float64
#  8   City              185950 non-null  object
#  9   Hour              185950 non-null  int64
#  10  Minute            185950 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(3), object(4)
# memory usage: 16.3+ MB

# %%
Products=all_data.groupby('Product').sum().reset_index()
Products
plt.bar(Products['Product'],Products['Quantity Ordered'])
plt.xticks(Products['Product'],rotation='vertical')
plt.xlabel("product")
plt.ylabel("sold_count")
plt.title("Number of products sold by each product")
plt.show()

# %%
prices=all_data.groupby('Product').mean().reset_index()
product=prices['Product']
price=prices['Price Each']
plt.plot(product,price)
plt.xticks(product,rotation='vertical')
plt.xlabel('products')
plt.ylabel('price')
plt.title('Price of each product')
plt.show()

# %%
price = prices['Price Each']

fig,ax1 = plt.subplots()

ax2 = ax1.twinx()

ax1.bar(Products['Product'],Products['Quantity Ordered'])
ax2.plot(Products['Product'],prices['Price Each'] , 'r')

ax1.set_xlabel('Products')
ax1.set_ylabel('quantiy', color='b')
ax2.set_ylabel('price', color='r')

ax1.set_xticklabels(Products['Product'],rotation='vertical')
ax2.set_yticklabels([])
plt.title('Quantity vs Price')

plt.show()
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_11748\3742765407.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(Products['Product'],rotation='vertical')

# %%
plt.pie(Products['Quantity Ordered'].astype(int),labels=Products['Product'],labeldistance=1.2)
plt.axis('equal')
plt.title('Contribution of products')

plt.show()

# %%
all_data_corr=all_data[['Quantity Ordered','Price Each','Month','Sales']].dropna().corr()

# %%
plt.scatter(x=all_data['Month'],y=all_data['Sales'])
plt.title('Sales vs Month')
plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(all_data,vars=['Quantity Ordered','Sales','Price Each','Month'],hue='Month')
plt.title('PAIR_PLOT EXAMPLE')
plt.show()

# %%
sns.heatmap(all_data_corr,annot=True)
plt.title("Correlation")
plt.show()

# %%
all_data.groupby('Product')['Quantity Ordered'].agg(['count']).plot(kind='barh')
plt.xlabel("Number of Orders")
plt.ylabel("Products")
plt.title("Number of Orders per Product")
plt.show()
